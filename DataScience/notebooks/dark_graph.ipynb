# %%
from dotenv import load_dotenv
from kaggle.api.kaggle_api_extended import KaggleApi

import pandas as pd
import os
import json

# %%
load_dotenv()

api = KaggleApi()
api.authenticate()

# Descarga un dataset
dataset = 'deepcontractor/dark-netflix-character-relationship'

dataset_folder = dataset.split(sep='/')[-1]

output_path = f'../datasets/{dataset_folder}/'  # Carpeta de descarga
api.dataset_download_files(dataset, path=output_path, unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/deepcontractor/dark-netflix-character-relationship

# %%
filepath = '../datasets/dark-netflix-character-relationship/characters.json'
if os.path.exists(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        docs = json.load(file)
    
docs
# Out:
# {'characters': [{'name': 'Daniel Kahnwald',
#    'lastname': 'Kahnwald',
#    'years': [1953],
#    'parentOf': ['Ines Kahnwald']},
#   {'name': 'Ines Kahnwald',
#    'lastname': 'Kahnwald',
#    'gender': 'female',
#    'parents': ['Daniel Kahnwald'],
#    'parentOf': ['Mikkel Nielsen'],
#    'years': [1953, 1986, 2019]},
#   {'name': 'Hannah Kahnwald',
#    'lastname': 'Kahnwald',
#    'married': ['Mikkel Nielsen'],
#    'parentOf': ['Jonas Kahnwald'],
#    'years': [1986, 2019]},
#   {'name': 'Jonas Kahnwald',
#    'lastname': 'Kahnwald',
#    'alias': ['Stranger', 'Adam'],
#    'years': [1921, 1953, 1986, 2019, 2052, 2085],
#    'parents': ['Hannah Kanhwald', 'Mikkel Nielsen'],
#    'sicMundus': True},
#   {'name': 'Ulrich Nielsen',
#    'firstname': 'Ulrich',
#    'lastname': 'Nielsen',
#    'years': [1953, 1986, 2019],
#    'gender': 'male',
#    'parents': ['Tronte Nielsen', 'Jana Nielsen'],
#    'parentOf': ['Mikkel Nielsen', 'Martha Nielsen', 'Magnus Nielsen'],
#    'married': ['Katharina Nielsen'],
#    'siblings': ['Mads Nielsen']},
#   {'name': 'Katharina Nielsen',
#    'firstname': 'Katharina',
#    'lastname': 'Nielsen',
#    'years': [1986, 2019],
#    'gender': 'female',
#    'parentOf': ['Mikkel Nielsen', 'Martha Nielsen', 'Magnus Nielsen'],
#    'married': ['Ulrich Nielsen']},
#   {'name': 'Mikkel Nielsen',
#    'firstname': 'Mikkel',
#    'lastname': 'Nielsen',
#    'alias': ['Michael Kahnwald'],
#    'years': [1986, 2019],
#    'gender': 'male',
#    'killedBy': ['Mikkel Nielsen'],
#    'married': 'Hannah Kahnwald',
#    'parentOf': ['Jonas Kahnwald'],
#    'parents': ['Katharina Nielsen', 'Ulrich Nielsen']},
#   {'name': 'Martha Nielsen',
#    'firstname': 'Martha',
#    'lastname': 'Nielsen',
#    'years': [2019, 2052],
#    'gender': 'female',
#    'siblings': ['Magnus Nielsen', 'Mikkel Nielsen'],
#    'parents': ['Ulrich Nielsen', 'Katharina Nielsen']},
#   {'name': 'Magnus Nielsen',
#    'firstname': 'Magnus',
#    'lastname': 'Nielsen',
#    'years': [1921, 2019, 2052],
#    'gender': 'male',
#    'siblings': ['Martha Nielsen', 'Mikkel Nielsen'],
#    'parents': ['Ulrich Nielsen', 'Katharina Nielsen'],
#    'sicMundus': True},
#   {'name': 'Mads Nielsen',
#    'firstname': 'Mads',
#    'lastname': 'Nielsen',
#    'years': [1986],
#    'gender': 'male',
#    'siblings': ['Ulrich Nielsen'],
#    'killedBy': ['Noah']},
#   {'name': 'Jana Nielsen',
#    'firstname': 'Jana',
#    'lastname': 'Nielsen',
#    'years': [1953, 1986, 2019],
#    'gender': 'female',
#    'parentOf': ['Ulrich Nielsen', 'Mads Nielsen'],
#    'married': ['Tronte Nielsen']},
#   {'name': 'Tronte Nielsen',
#    'firstname': 'Tronte',
#    'lastname': 'Nielsen',
#    'years': [1953, 1986, 2019],
#    'gender': 'male',
#    'parentOf': ['Ulrich Nielsen', 'Mads Nielsen', 'Regina Tiedeman'],
#    'parents': ['Agnes Nielsen'],
#    'married': ['Jana Nielsen']},
#   {'name': 'Agnes Nielsen',
#    'firstname': 'Agnes',
#    'lastname': 'Nielsen',
#    'years': [1921, 1953],
#    'gender': 'female',
#    'parentOf': ['Tronte Nielsen'],
#    'siblings': ['Noah'],
#    'sicMundus': True},
#   {'name': 'Charlotte Doppler',
#    'firstname': 'Charlotte',
#    'lastname': 'Doppler',
#    'years': [1986, 2019],
#    'gender': 'female',
#    'parents': ['Elisabeth Doppler', 'Noah'],
#    'married': ['Peter Doppler'],
#    'parentOf': ['Franziska Doppler', 'Elisabeth Doppler']},
#   {'name': 'Peter Doppler',
#    'firstname': 'Peter',
#    'lastname': 'Doppler',
#    'years': [2019],
#    'gender': 'male',
#    'married': ['Charlotte Doppler'],
#    'parentOf': ['Franziska Doppler', 'Elisabeth Doppler'],
#    'parents': ['Helge Doppler']},
#   {'name': 'Elisabeth Doppler',
#    'firstname': 'Elisabeth',
#    'lastname': 'Doppler',
#    'years': [2019, 2052],
#    'gender': 'female',
#    'siblings': ['Franziska Doppler'],
#    'parentOf': ['Charlotte Doppler'],
#    'parents': ['Peter Doppler', 'Charlotte Doppler']},
#   {'name': 'Franziska Doppler',
#    'firstname': 'Franziska',
#    'lastname': 'Doppler',
#    'years': [1921, 2019],
#    'gender': 'female',
#    'siblings': ['Elisabeth Doppler'],
#    'parents': ['Charlotte Doppler', 'Peter Doppler'],
#    'sicMundus': True},
#   {'name': 'Helge Doppler',
#    'firstname': 'Helge',
#    'lastname': 'Doppler',
#    'years': [1953, 1986, 2019],
#    'gender': 'male',
#    'parentOf': 'Peter Doppler',
#    'parents': ['Bernd Doppler', 'Greta Doppler'],
#    'killedBy': ['Helge Doppler']},
#   {'name': 'Greta Doppler',
#    'firstname': 'Greta',
#    'lastname': 'Doppler',
#    'years': [1953],
#    'gender': 'female',
#    'parentOf': ['Helge Doppler'],
#    'married': ['Bernd Doppler']},
#   {'name': 'Bernd Doppler',
#    'firstname': 'Bernd',
#    'lastname': 'Doppler',
#    'years': [1953, 1986],
#    'gender': 'male',
#    'parentOf': ['Helge Doppler'],
#    'married': ['Greta Doppler']},
#   {'name': 'Yasin Friese',
#    'firstname': 'Yasin',
#    'lastname': 'Friese',
#    'years': [2019],
#    'gender': 'male'},
#   {'name': 'Aleksander Tiedeman',
#    'firstname': 'Aleksander',
#    'lastname': 'Tiedeman',
#    'years': [1986, 2019],
#    'gender': 'male',
#    'alias': ['Boris Niewald'],
#    'parentOf': ['Bartosz Tiedeman'],
#    'married': ['Regina Tiedeman']},
#   {'name': 'Regina Tiedeman',
#    'firstname': 'Regina',
#    'lastname': 'Tiedeman',
#    'years': [1986, 2019],
#    'gender': 'female',
#    'parents': ['Tronte Nielsen', 'Claudia Tiedeman'],
#    'parentOf': ['Bartoz Tiedeman'],
#    'married': ['Aleksander Tiedeman']},
#   {'name': 'Bartosz Tiedeman',
#    'firstname': 'Bartosz',
#    'lastname': 'Tiedeman',
#    'years': [2019],
#    'gender': 'male',
#    'parents': ['Regina Tiedeman', 'Aleksander Tiedeman']},
#   {'name': 'Claudia Tiedeman',
#    'firstname': 'Claudia',
#    'lastname': 'Tiedeman',
#    'years': [1953, 1986, 2019],
#    'gender': 'female',
#    'parentOf': ['Regina Tiedeman'],
#    'parents': ['Egon Tiedeman', 'Doris Tiedeman'],
#    'killedBy': ['Noah']},
#   {'name': 'Egon Tiedeman',
#    'firstname': 'Egon',
#    'lastname': 'Tiedeman',
#    'years': [1986, 2019],
#    'gender': 'female',
#    'parentOf': ['Claudia Tiedeman'],
#    'parents': ['Doris Tiedeman']},
#   {'name': 'Doris Tiedeman',
#    'firstname': 'Doris',
#    'lastname': 'Tiedeman',
#    'years': [1953],
#    'gender': 'female',
#    'parentOf': ['Claudia Tiedeman'],
#    'married': ['Egon Tiedeman']},
#   {'name': 'Ulla Obendorf',
#    'firstname': 'Ulla',
#    'lastname': 'Obendorf',
#    'years': [2019],
#    'gender': 'female'},
#   {'name': 'Jurgen Obendorf',
#    'firstname': 'Jurgen',
#    'lastname': 'Obendorf',
#    'years': [2019],
#    'gender': 'male'},
#   {'name': 'Erik Obendorf',
#    'firstname': 'Erik',
#    'lastname': 'Obendorf',
#    'years': [2019],
#    'gender': 'male'},
#   {'name': 'Noah',
#    'firstname': 'Noah',
#    'lastname': 'Nielsen',
#    'years': [1921, 1953, 1986, 2019],
#    'gender': 'male',
#    'siblings': ['Agnes Nielsen'],
#    'parentOf': ['Charlotte Doppler'],
#    'sicMundus': True,
#    'killedBy': ['Agnes Nielsen']},
#   {'name': 'H.G. Tannhaus', 'lastname': 'Tannhaus', 'years': [1953, 1986]},
#   {'name': 'Clausen', 'lastname': 'Clausen', 'years': [2019]},
#   {'name': 'Torben Woller', 'lastname': 'Woller', 'years': [2019]}]}

# %%
import matplotlib.colors as mcolors

df = pd.json_normalize(docs['characters'])

df = df.drop(columns=['alias', 'sicMundus', 'gender', 'firstname',
                      'parents', 'killedBy', 'years'])

# Obtener una lista de colores únicos
unique_lastnames = df['lastname'].unique()
colors = list(mcolors.TABLEAU_COLORS.values())  # Usa una paleta de colores predefinida

# Asignar un color a cada apellido
color_map = {name: colors[i % len(colors)] for i, name in enumerate(unique_lastnames)}

# Agregar la columna de color al DataFrame
df['color'] = df['lastname'].map(color_map)

df.head(10)
# Out:
#                 name  lastname  \
# 0    Daniel Kahnwald  Kahnwald
# 1      Ines Kahnwald  Kahnwald
# 2    Hannah Kahnwald  Kahnwald
# 3     Jonas Kahnwald  Kahnwald
# 4     Ulrich Nielsen   Nielsen
# 5  Katharina Nielsen   Nielsen
# 6     Mikkel Nielsen   Nielsen
# 7     Martha Nielsen   Nielsen
# 8     Magnus Nielsen   Nielsen
# 9       Mads Nielsen   Nielsen
#
#                                            parentOf              married  \
# 0                                   [Ines Kahnwald]                  NaN
# 1                                  [Mikkel Nielsen]                  NaN
# 2                                  [Jonas Kahnwald]     [Mikkel Nielsen]
# 3                                               NaN                  NaN
# 4  [Mikkel Nielsen, Martha Nielsen, Magnus Nielsen]  [Katharina Nielsen]
# 5  [Mikkel Nielsen, Martha Nielsen, Magnus Nielsen]     [Ulrich Nielsen]
# 6                                  [Jonas Kahnwald]      Hannah Kahnwald
# 7                                               NaN                  NaN
# 8                                               NaN                  NaN
# 9                                               NaN                  NaN
#
#                            siblings    color
# 0                               NaN  #1f77b4
# 1                               NaN  #1f77b4
# 2                               NaN  #1f77b4
# 3                               NaN  #1f77b4
# 4                    [Mads Nielsen]  #ff7f0e
# 5                               NaN  #ff7f0e
# 6                               NaN  #ff7f0e
# 7  [Magnus Nielsen, Mikkel Nielsen]  #ff7f0e
# 8  [Martha Nielsen, Mikkel Nielsen]  #ff7f0e
# 9                  [Ulrich Nielsen]  #ff7f0e

# %%
df['married'] = df['married'].apply(lambda x: x[0] if isinstance(x, list) else x)

df_marrieds = df[['name', 'married']].drop_duplicates().dropna().copy()
df_marrieds.columns = ['source', 'target']
df_marrieds['Relationship'] = 'Married'
df_marrieds['Color'] = 'green'

df_marrieds.head()
# Out:
#                source             target Relationship  Color
# 2     Hannah Kahnwald     Mikkel Nielsen      Married  green
# 4      Ulrich Nielsen  Katharina Nielsen      Married  green
# 5   Katharina Nielsen     Ulrich Nielsen      Married  green
# 6      Mikkel Nielsen    Hannah Kahnwald      Married  green
# 10       Jana Nielsen     Tronte Nielsen      Married  green

# %%
df_sibb = df[['name', 'siblings']].explode('siblings').drop_duplicates().dropna().copy()
df_sibb.columns = ['source', 'target']
df_sibb['Relationship'] = 'Sibblings'
df_sibb['Color'] = 'orange'

df_sibb.head()
# Out:
#            source          target Relationship   Color
# 4  Ulrich Nielsen    Mads Nielsen    Sibblings  orange
# 7  Martha Nielsen  Magnus Nielsen    Sibblings  orange
# 7  Martha Nielsen  Mikkel Nielsen    Sibblings  orange
# 8  Magnus Nielsen  Martha Nielsen    Sibblings  orange
# 8  Magnus Nielsen  Mikkel Nielsen    Sibblings  orange

# %%
df_parenthood = df[['name', 'parentOf']].explode('parentOf').dropna().copy()
df_parenthood.columns = ['source', 'target']
df_parenthood['Relationship'] = 'Parent-Child'
df_parenthood['Color'] = 'gray'

df_parenthood.head()
# Out:
#             source          target  Relationship Color
# 0  Daniel Kahnwald   Ines Kahnwald  Parent-Child  gray
# 1    Ines Kahnwald  Mikkel Nielsen  Parent-Child  gray
# 2  Hannah Kahnwald  Jonas Kahnwald  Parent-Child  gray
# 4   Ulrich Nielsen  Mikkel Nielsen  Parent-Child  gray
# 4   Ulrich Nielsen  Martha Nielsen  Parent-Child  gray

# %%
import networkx as nx

# df_edges = pd.concat([df_parenthood, df_marrieds, df_sibb], axis=0)
df_edges = pd.concat([df_parenthood, df_marrieds], axis=0)

G = nx.from_pandas_edgelist(df_edges, source='source', target='target', edge_attr=['Relationship', 'Color'], create_using=nx.Graph)

# Calcular el grado de cada nodo
degree_dict = dict(G.degree())

# Asignar el grado como atributo a cada nodo
nx.set_node_attributes(G, degree_dict, name="degree")

attributes = df[['name', 'color']].set_index('name').to_dict('index')
nx.set_node_attributes(G, attributes)

df_edges.head()
# Out:
#             source          target  Relationship Color
# 0  Daniel Kahnwald   Ines Kahnwald  Parent-Child  gray
# 1    Ines Kahnwald  Mikkel Nielsen  Parent-Child  gray
# 2  Hannah Kahnwald  Jonas Kahnwald  Parent-Child  gray
# 4   Ulrich Nielsen  Mikkel Nielsen  Parent-Child  gray
# 4   Ulrich Nielsen  Martha Nielsen  Parent-Child  gray

# %%
print(G.nodes())
print(G.nodes(data=True))
print(G.edges(data=True))
# Out:
# ['Daniel Kahnwald', 'Ines Kahnwald', 'Mikkel Nielsen', 'Hannah Kahnwald', 'Jonas Kahnwald', 'Ulrich Nielsen', 'Martha Nielsen', 'Magnus Nielsen', 'Katharina Nielsen', 'Jana Nielsen', 'Mads Nielsen', 'Tronte Nielsen', 'Regina Tiedeman', 'Agnes Nielsen', 'Charlotte Doppler', 'Franziska Doppler', 'Elisabeth Doppler', 'Peter Doppler', 'Helge Doppler', 'Greta Doppler', 'Bernd Doppler', 'Aleksander Tiedeman', 'Bartosz Tiedeman', 'Bartoz Tiedeman', 'Claudia Tiedeman', 'Egon Tiedeman', 'Doris Tiedeman', 'Noah']
# [('Daniel Kahnwald', {'degree': 1, 'color': '#1f77b4'}), ('Ines Kahnwald', {'degree': 2, 'color': '#1f77b4'}), ('Mikkel Nielsen', {'degree': 5, 'color': '#ff7f0e'}), ('Hannah Kahnwald', {'degree': 2, 'color': '#1f77b4'}), ('Jonas Kahnwald', {'degree': 2, 'color': '#1f77b4'}), ('Ulrich Nielsen', {'degree': 6, 'color': '#ff7f0e'}), ('Martha Nielsen', {'degree': 2, 'color': '#ff7f0e'}), ('Magnus Nielsen', {'degree': 2, 'color': '#ff7f0e'}), ('Katharina Nielsen', {'degree': 4, 'color': '#ff7f0e'}), ('Jana Nielsen', {'degree': 3, 'color': '#ff7f0e'}), ('Mads Nielsen', {'degree': 2, 'color': '#ff7f0e'}), ('Tronte Nielsen', {'degree': 5, 'color': '#ff7f0e'}), ('Regina Tiedeman', {'degree': 4, 'color': '#9467bd'}), ('Agnes Nielsen', {'degree': 1, 'color': '#ff7f0e'}), ('Charlotte Doppler', {'degree': 4, 'color': '#2ca02c'}), ('Franziska Doppler', {'degree': 2, 'color': '#2ca02c'}), ('Elisabeth Doppler', {'degree': 2, 'color': '#2ca02c'}), ('Peter Doppler', {'degree': 4, 'color': '#2ca02c'}), ('Helge Doppler', {'degree': 3, 'color': '#2ca02c'}), ('Greta Doppler', {'degree': 2, 'color': '#2ca02c'}), ('Bernd Doppler', {'degree': 2, 'color': '#2ca02c'}), ('Aleksander Tiedeman', {'degree': 2, 'color': '#9467bd'}), ('Bartosz Tiedeman', {'degree': 1, 'color': '#9467bd'}), ('Bartoz Tiedeman', {'degree': 1}), ('Claudia Tiedeman', {'degree': 3, 'color': '#9467bd'}), ('Egon Tiedeman', {'degree': 2, 'color': '#9467bd'}), ('Doris Tiedeman', {'degree': 2, 'color': '#9467bd'}), ('Noah', {'degree': 1, 'color': '#ff7f0e'})]
# [('Daniel Kahnwald', 'Ines Kahnwald', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Ines Kahnwald', 'Mikkel Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Mikkel Nielsen', 'Ulrich Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Mikkel Nielsen', 'Katharina Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Mikkel Nielsen', 'Jonas Kahnwald', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Mikkel Nielsen', 'Hannah Kahnwald', {'Relationship': 'Married', 'Color': 'green'}), ('Hannah Kahnwald', 'Jonas Kahnwald', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Ulrich Nielsen', 'Martha Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Ulrich Nielsen', 'Magnus Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Ulrich Nielsen', 'Jana Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Ulrich Nielsen', 'Tronte Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Ulrich Nielsen', 'Katharina Nielsen', {'Relationship': 'Married', 'Color': 'green'}), ('Martha Nielsen', 'Katharina Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Magnus Nielsen', 'Katharina Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Jana Nielsen', 'Mads Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Jana Nielsen', 'Tronte Nielsen', {'Relationship': 'Married', 'Color': 'green'}), ('Mads Nielsen', 'Tronte Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Tronte Nielsen', 'Regina Tiedeman', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Tronte Nielsen', 'Agnes Nielsen', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Regina Tiedeman', 'Bartoz Tiedeman', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Regina Tiedeman', 'Claudia Tiedeman', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Regina Tiedeman', 'Aleksander Tiedeman', {'Relationship': 'Married', 'Color': 'green'}), ('Charlotte Doppler', 'Franziska Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Charlotte Doppler', 'Elisabeth Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Charlotte Doppler', 'Noah', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Charlotte Doppler', 'Peter Doppler', {'Relationship': 'Married', 'Color': 'green'}), ('Franziska Doppler', 'Peter Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Elisabeth Doppler', 'Peter Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Peter Doppler', 'Helge Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Helge Doppler', 'Greta Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Helge Doppler', 'Bernd Doppler', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Greta Doppler', 'Bernd Doppler', {'Relationship': 'Married', 'Color': 'green'}), ('Aleksander Tiedeman', 'Bartosz Tiedeman', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Claudia Tiedeman', 'Egon Tiedeman', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Claudia Tiedeman', 'Doris Tiedeman', {'Relationship': 'Parent-Child', 'Color': 'gray'}), ('Egon Tiedeman', 'Doris Tiedeman', {'Relationship': 'Married', 'Color': 'green'})]

# %%
from bokeh.models import Circle, MultiLine, NodesAndLinkedEdges, HoverTool, ColumnDataSource, LabelSet, Arrow, NormalHead
from bokeh.plotting import figure, from_networkx, output_file, save, show
from bokeh.io import output_notebook
from bokeh.models.tools import BoxZoomTool

# Habilitar la visualización en Jupyter Notebook
output_notebook()

node_highlight_color = 'white'
edge_highlight_color = 'darkblue'

# Create a figure
plot = figure(
    title='Grafo con Bokeh', 
    height=600,
    width=600,
    tools='pan,wheel_zoom,zoom_in,zoom_out,save, reset')

# Ocultar cuadrícula
plot.grid.visible = False
plot.axis.visible = False
plot.xaxis.axis_label = None
plot.yaxis.axis_label = None
plot.xaxis.major_label_text_font_size = '0pt'
plot.yaxis.major_label_text_font_size = '0pt'

# Add a selection tool to zoom in
plot.add_tools(BoxZoomTool())

# Add the graph with the specified posititons
pos = nx.spring_layout(G, weight="degree", seed=42)
graph_renderer = from_networkx(G, pos)

# Set edges' attributes
graph_renderer.edge_renderer.data_source.data['color'] = [G[u][v]['Color'] for u, v in G.edges()]

# Configure edges
graph_renderer.edge_renderer.glyph = MultiLine(line_color='color', line_width=1.5, line_alpha=0.9)
graph_renderer.edge_renderer.selection_glyph = MultiLine(line_color=edge_highlight_color, line_width=2)
graph_renderer.edge_renderer.hover_glyph = MultiLine(line_color=edge_highlight_color, line_width=2)

# Set nodes' attributes
graph_renderer.node_renderer.data_source.data['Name'] = [node for node in G.nodes()]
graph_renderer.node_renderer.data_source.data['Color'] = [data.get('color', 'gray') for node, data in G.nodes(data=True)]
graph_renderer.node_renderer.data_source.data['Degree'] = [degree_dict[n] for n in G.nodes]
graph_renderer.node_renderer.data_source.data['Size'] = [degree_dict[n]*0.5e-2 for n in G.nodes]

# Add hover tool for nodes
hover_tool = HoverTool(
    tooltips=[
        ('Name', '@Name'),
        ('Degree', '@Degree'),
    ]
)
plot.add_tools(hover_tool)

# Configure nodes
graph_renderer.node_renderer.glyph = Circle(fill_color='Color', radius='Size', line_width=0, line_color='white')
graph_renderer.node_renderer.hover_glyph = Circle(radius='Size', fill_color=node_highlight_color, line_width=2)
graph_renderer.node_renderer.selection_glyph = Circle(radius='Size', fill_color=node_highlight_color, line_width=2)

# Separar nombres y apellidos
# names = list(G.nodes)
names = [node for node, data in G.nodes(data=True) if data['degree'] > 4]
first_names = [name.split()[0] if len(name.split()) > 0 else "" for name in names]
last_names = [name.split()[1] if len(name.split()) > 1 else "" for name in names]

# Crear un ColumnDataSource con posiciones para etiquetas
node_x = [pos[n][0] for n in names]
node_y = [pos[n][1] + 0.05 for n in names]  # Ajuste para que las etiquetas queden arriba del nodo

# Agregar etiquetas con nombres y apellidos en dos líneas
label_source = ColumnDataSource(data={'x': node_x, 'y': node_y, 'first_name': first_names})
labels = LabelSet(
    x='x', y='y', text='first_name', source=label_source,
    text_align='center', text_baseline='bottom', text_font_size='8pt',
    text_color='gray'
)
plot.add_layout(labels)

label_source = ColumnDataSource(data={'x': node_x, 'y': node_y, 'last_names': last_names})
labels = LabelSet(
    x='x', y='y', text='last_names', source=label_source,
    text_align='center', text_baseline='top', text_font_size='8pt',
    text_color='gray'
)
plot.add_layout(labels)

# Highlight nodes and edges
graph_renderer.selection_policy = NodesAndLinkedEdges()
graph_renderer.inspection_policy = NodesAndLinkedEdges()

plot.renderers.append(graph_renderer)

show(plot)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fe4d550f-ff44-4431-a1bb-4ff9e9888fea">Loading BokehJS ...</span>
#     </div>
#   <div id="cc1914e5-023b-4384-8d62-e419c9988fa5" data-root-id="p13261" style="display: contents;"></div>

# %%
graph_name = 'bokeh_graph.html'
graph_file = os.path.join('outputs', 'Graphs')
os.makedirs(graph_file, exist_ok=True)
graph_file = os.path.join(graph_file, graph_name)

# Save as HTML
output_file(graph_file)
save(plot)

# %%
# # Agregar flechas en las conexiones
# for start_node, end_node in G.edges():
#     x_start, y_start = pos[start_node]
#     x_end, y_end = pos[end_node]

#     arrow = Arrow(
#         end=NormalHead(size=5, fill_color="gray", line_color="gray"),
#         x_start=x_start, y_start=y_start,
#         x_end=x_end, y_end=y_end,
#         line_color="gray", line_width=0
#     )
#     plot.add_layout(arrow)
